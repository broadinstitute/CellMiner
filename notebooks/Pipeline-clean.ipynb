# %%
import sys
pkg_path = '/home/jupyter/code'
if pkg_path not in sys.path:
    sys.path.append(pkg_path)

import torch

from optical_electrophysiology import entire_pipeline

use_gpu = True
if use_gpu and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
# %load_ext autoreload
# %autoreload 2

# %%
entire_pipeline(bucket='gs://broad-opp-voltage/2020-07-23_VoltageMovies_SCDN011', result_folder='results_new', 
                bin_files='153316_1992_NR_d4inf_freezethaw_D32_FOV1', delete_local_data=False, device=device)
# Out:
# Create folder 2020-07-23_VoltageMovies_SCDN011/results_new
# Process 153316_1992_NR_d4inf_freezethaw_D32_FOV1
# Create folder 2020-07-23_VoltageMovies_SCDN011/results_new/153316_1992_NR_d4inf_freezethaw_D32_FOV1
# 15 neuron detected in 153316_1992_NR_d4inf_freezethaw_D32_FOV1.bin
# 26.26070213317871
